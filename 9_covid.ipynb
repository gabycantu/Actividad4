# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cufflinks as cf
from IPython.display import display,HTML

# %%
#Leo mi archivo.csv
covid = pd.read_csv("COVID19Mexico.csv")
# Out:
# /var/folders/h7/3hswkg9n4t7_f3vwwzsc1gv40000gn/T/ipykernel_91374/4140251673.py:2: DtypeWarning:
#
# Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
valores_nulos=covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   1
# ENTIDAD_UM               1
# SEXO                     1
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            1
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     3
# NACIONALIDAD             0
# EMBARAZO                 2
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             1
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# ...

# %%
covid.head()
# Out:
#    Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0           0          27/08/2022      1a4a8d       1    12.0        23.0
# 1           1          27/08/2022      01e27d       2     9.0        25.0
# 2           2          27/08/2022      13cf10       2     9.0         9.0
# 3           3          27/08/2022      13c92b       2    12.0         9.0
# 4           4          27/08/2022      04af5f       2    12.0         9.0
#
#    SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  ...  OTRO_CASO  \
# 0   2.0           27           23            8.0  ...        2.0
# 1   2.0           25           25            1.0  ...        2.0
# 2   1.0            9            9           14.0  ...        2.0
# 3   1.0            9            9            2.0  ...        1.0
# 4   1.0            9            9            7.0  ...        1.0
#
#   TOMA_MUESTRA_LAB RESULTADO_LAB TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  \
# ...

# %%
#Sustituir valores nulos con promedio o media
covid["EDAD"]=covid["EDAD"].fillna(round(covid["EDAD"].mean(),1))
covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2     NaN         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         NaN
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
valores_nulos=covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   1
# ENTIDAD_UM               1
# SEXO                     1
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            1
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 2
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             1
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# ...

# %%
covid["SECTOR"] =covid["SECTOR"].fillna(method="ffill") 
covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2    12.0         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         NaN
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
valores_nulos=covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               1
# SEXO                     1
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            1
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 2
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             1
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# ...

# %%
covid["ENTIDAD_UM"] =covid["ENTIDAD_UM"].fillna(method="ffill") 
covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2    12.0         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         9.0
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
valores_nulos=covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               0
# SEXO                     1
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            1
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 2
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             1
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# ...

# %%
#Sustituir valores nulos con mediana
covid["SEXO"]=covid["SEXO"].fillna(round(covid["SEXO"].median(),1))
covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2    12.0         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         9.0
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
valores_nulos=covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               0
# SEXO                     0
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            1
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 2
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             1
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# ...

# %%
#Sustituir valores nulos con mediana
covid["MUNICIPIO_RES"]=covid["MUNICIPIO_RES"].fillna(round(covid["MUNICIPIO_RES"].median(),1))
covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2    12.0         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         9.0
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
valores_nulos=covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               0
# SEXO                     0
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            0
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 2
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             1
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# ...

# %%
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
covid["EMBARAZO"] =covid["EMBARAZO"].fillna(method="bfill") 
covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2    12.0         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         9.0
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
valores_nulos=covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               0
# SEXO                     0
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            0
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 0
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             1
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# ...

# %%
#Sustituir valores nulos por un valor numérico en  concreto 
covid["PAIS_NACIONALIDAD"]= covid["PAIS_NACIONALIDAD"].fillna("México") 
covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2    12.0         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         9.0
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
valores_nulos=covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               0
# SEXO                     0
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            0
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 0
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             1
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# ...

# %%
#Sustituir valores nulos con mediana
covid["HIPERTENSION"]=covid["HIPERTENSION"].fillna(round(covid["HIPERTENSION"].median(),1))
covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2    12.0         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         9.0
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
valores_nulos=covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               0
# SEXO                     0
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            0
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 0
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             0
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# ...

# %%
#Sustituir valores nulos con mediana
covid["TABAQUISMO"]=covid["TABAQUISMO"].fillna(round(covid["TABAQUISMO"].median(),1))
covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2    12.0         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         9.0
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
valores_nulos=covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               0
# SEXO                     0
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            0
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 0
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             0
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               0
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# ...

# %%
#Sustituir valores nulos con moda
covid["OTRO_CASO"]=covid["OTRO_CASO"].fillna(round(covid["OTRO_CASO"].median(),1))
covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2    12.0         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         9.0
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
valores_nulos=covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               0
# SEXO                     0
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            0
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 0
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             0
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               0
# OTRO_CASO                0
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# ...

# %%
#Sustituir valores nulos con moda
covid["RESULTADO_ANTIGENO"]=covid["RESULTADO_ANTIGENO"].fillna(round(covid["RESULTADO_ANTIGENO"].median(),1))
covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2    12.0         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         9.0
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
valores_nulos=covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               0
# SEXO                     0
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            0
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 0
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             0
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               0
# OTRO_CASO                0
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# ...

# %%
Cuenta_Total_Nulos= covid.isnull().sum().sum()
Cuenta_Total_Nulos
# Out:
# 0

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=covid["EDAD"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 81.0
# Limite inferior permitido -7.0

# %%
#Encontramos Ouliers
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 51             51          27/08/2022      100caf       1     6.0        17.0
# 159           159          27/08/2022      31c7f5       1    12.0         9.0
# 250           250          27/08/2022      3a2068       1    12.0         3.0
# 337           337          27/08/2022      4f8b86       2    12.0        22.0
# 538           538          27/08/2022      7f6947       2    12.0        14.0
# ...           ...                 ...         ...     ...     ...         ...
# 98183       98183          27/08/2022      b3c459       2     6.0        24.0
# 98851       98851          27/08/2022      d2ba66       2     4.0        25.0
# 98908       98908          27/08/2022      b8ca22       2    12.0        32.0
# 98918       98918          27/08/2022      b25c23       1     4.0         9.0
# 99914       99914          27/08/2022      52d37f       2    12.0        11.0
#
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2    12.0         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         9.0
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["EDAD"]) 
plt.title("Outliers de EDAD")
plt.show() #dibujamos el diagrama
